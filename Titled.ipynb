# %%
import pandas as pd

df = pd.read_json('data/data.json')

# %%
df.columns
# Out:
# Index(['acct_type', 'approx_payout_date', 'body_length', 'channels', 'country',
#        'currency', 'delivery_method', 'description', 'email_domain',
#        'event_created', 'event_end', 'event_published', 'event_start',
#        'fb_published', 'gts', 'has_analytics', 'has_header', 'has_logo',
#        'listed', 'name', 'name_length', 'num_order', 'num_payouts',
#        'object_id', 'org_desc', 'org_facebook', 'org_name', 'org_twitter',
#        'payee_name', 'payout_type', 'previous_payouts', 'sale_duration',
#        'sale_duration2', 'show_map', 'ticket_types', 'user_age',
#        'user_created', 'user_type', 'venue_address', 'venue_country',
#        'venue_latitude', 'venue_longitude', 'venue_name', 'venue_state'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 44

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
df.describe().T
# Out:
#                       count          mean           std           min  \
# approx_payout_date  14337.0  1.350933e+09  2.401300e+07  1.171256e+09
# body_length         14337.0  3.672522e+03  5.758113e+03  0.000000e+00
# channels            14337.0  6.176676e+00  3.860333e+00  0.000000e+00
# delivery_method     14321.0  4.395643e-01  5.914866e-01  0.000000e+00
# event_created       14337.0  1.345825e+09  2.404107e+07  1.170332e+09
# event_end           14337.0  1.350501e+09  2.401299e+07  1.170824e+09
# event_published     14238.0  1.340854e+09  8.750386e+07  0.000000e+00
# event_start         14337.0  1.350205e+09  2.398787e+07  1.170819e+09
# fb_published        14337.0  1.274325e-01  3.334685e-01  0.000000e+00
# gts                 14337.0  2.430231e+03  9.142308e+03  0.000000e+00
# has_analytics       14337.0  7.302783e-02  2.601913e-01  0.000000e+00
# has_header           8928.0  2.020609e-01  4.015599e-01  0.000000e+00
# ...

# %%
df.head(20).T
# Out:
#                                                                    0   \
# acct_type                                             fraudster_event
# approx_payout_date                                         1266062400
# body_length                                                      3852
# channels                                                            5
# country                                                            US
# currency                                                          USD
# delivery_method                                                     0
# description         <p><a href="http://s432.photobucket.com/albums...
# email_domain                                                gmail.com
# event_created                                              1262739706
# event_end                                                  1265630400
# event_published                                           1.26311e+09
# ...

# %%
df['acct_type'].value_counts()
# Out:
# premium             12373
# fraudster_event       851
# fraudster             437
# spammer_limited       218
# spammer_warn          144
# tos_warn               91
# spammer_noinvite       84
# tos_lock               77
# locked                 54
# fraudster_att           5
# spammer_web             2
# spammer                 1
# Name: acct_type, dtype: int64

# %%
# what looks like fraud or not fraud? 
# is is_premium dummy a 100% predictor of fraud?

# %%
df['description'].head()
# Out:
# 0    <p><a href="http://s432.photobucket.com/albums...
# 1    <p>Join us for a quick, one-night, community-b...
# 2    <h3><span class="subcategory"><strong>Teacher ...
# 3    <p style="margin-bottom: 1.3em; padding-bottom...
# 4    <p>Writers and filmmakers need to understand t...
# Name: description, dtype: object

# %%
df['description'].iloc[0]
# Out:
# '<p><a href="http://s432.photobucket.com/albums/qq49/digusonline/?action=view&amp;current=supersunday.jpg" target="_blank"><img src="http://i432.photobucket.com/albums/qq49/digusonline/supersunday.jpg" border="0" alt="Photobucket" /></a></p>\r\n<p>\xa0</p>\r\n<p style="text-align: center;"><font size="3"><strong>Party Starz Entertaintment &amp; Diverse International Group Presents...<br /></strong></font><br /><font face="tahoma,arial,helvetica,sans-serif" size="4"><strong>The Official\xa0"99 Hour No Sleep" Super Bowl </strong></font></p>\r\n<p style="text-align: center;"><font face="tahoma,arial,helvetica,sans-serif" size="4"><strong>Weekend </strong></font><font face="tahoma,arial,helvetica,sans-serif" size="4"><strong>Grand Finale</strong></font></p>\r\n<p><br /><span style="font-family: Times New Roman,serif;"><font size="3"><font face="tahoma,arial,helvetica,sans-serif">No matter who wins or loses, this post-game party cannot be missed! Enjoy the drink specials and all night mus
# ...

# %%
df.channels.value_counts()
# Out:
# 8     3364
# 0     2941
# 5     2459
# 11    2312
# 6     1736
# 4      556
# 12     470
# 10     237
# 13     232
# 9       20
# 7       10
# Name: channels, dtype: int64

# %%
df.columns
# Out:
# Index(['acct_type', 'approx_payout_date', 'body_length', 'channels', 'country',
#        'currency', 'delivery_method', 'description', 'email_domain',
#        'event_created', 'event_end', 'event_published', 'event_start',
#        'fb_published', 'gts', 'has_analytics', 'has_header', 'has_logo',
#        'listed', 'name', 'name_length', 'num_order', 'num_payouts',
#        'object_id', 'org_desc', 'org_facebook', 'org_name', 'org_twitter',
#        'payee_name', 'payout_type', 'previous_payouts', 'sale_duration',
#        'sale_duration2', 'show_map', 'ticket_types', 'user_age',
#        'user_created', 'user_type', 'venue_address', 'venue_country',
#        'venue_latitude', 'venue_longitude', 'venue_name', 'venue_state'],
#       dtype='object')

# %%
small_df = df.drop(['acct_type', 'approx_payout_date', 'channels', 'description', 'event_created', 'event_end', 'event_published', 'event_start', 'gts', 'has_analytics', 'listed', 'name', 'num_payouts', 'object_id', 'org_desc', 'org_name', 'payee_name', 'venue_address', 'venue_latitude', 'venue_longitude', 'venue_name'], axis = 1)

# %%
# maybe in future: 
# description, channels, relevant times, has_analytics, listed, num_payouts, 
# for nlp: description, name, org_desc,

# %%
small_df.head()
# Out:
#    body_length country currency  delivery_method                email_domain  \
# 0         3852      US      USD              0.0                   gmail.com
# 1         3499      US      USD              1.0                     ruf.org
# 2         2601      US      USD              1.0              pvsd.k12.ca.us
# 3        12347      IE      EUR              1.0        irishtabletennis.com
# 4         2417      US      USD              0.0  artsandbusinesscouncil.org
#
#    fb_published  has_header  has_logo  name_length  num_order     ...       \
# 0             0         1.0         0           60          0     ...
# 1             0         0.0         1           27         23     ...
# 2             0         NaN         0           28         19     ...
# 3             0         0.0         1           21         39     ...
# 4             1         0.0         0           66         30     ...
#
#                                     previous_payouts  sale_duration  \
# ...

# %%
small_df.columns
# Out:
# Index(['body_length', 'country', 'currency', 'delivery_method', 'email_domain',
#        'fb_published', 'has_header', 'has_logo', 'name_length', 'num_order',
#        'org_facebook', 'org_twitter', 'payout_type', 'previous_payouts',
#        'sale_duration', 'sale_duration2', 'show_map', 'ticket_types',
#        'user_age', 'user_created', 'user_type', 'venue_country',
#        'venue_state'],
#       dtype='object')

# %%
small_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14337 entries, 0 to 14336
# Data columns (total 23 columns):
# body_length         14337 non-null int64
# country             14256 non-null object
# currency            14337 non-null object
# delivery_method     14321 non-null float64
# email_domain        14337 non-null object
# fb_published        14337 non-null int64
# has_header          8928 non-null float64
# has_logo            14337 non-null int64
# name_length         14337 non-null int64
# num_order           14337 non-null int64
# org_facebook        14278 non-null float64
# org_twitter         14278 non-null float64
# payout_type         14337 non-null object
# previous_payouts    14337 non-null object
# sale_duration       14182 non-null float64
# sale_duration2      14337 non-null int64
# show_map            14337 non-null int64
# ticket_types        14337 non-null object
# user_age            14337 non-null int64
# user_created        14337 non-null int64
# ...

# %%
df['has_header'].value_counts()
# Out:
# 0.0    7124
# 1.0    1804
# Name: has_header, dtype: int64

# %%
smaller_df = small_df.drop(['country', 'currency', 'email_domain', 'payout_type', 'previous_payouts', 'ticket_types', 'venue_country', 'venue_state'], axis = 1)

# %%
smaller_df.head()
# Out:
#    body_length  delivery_method  fb_published  has_header  has_logo  \
# 0         3852              0.0             0         1.0         0
# 1         3499              1.0             0         0.0         1
# 2         2601              1.0             0         NaN         0
# 3        12347              1.0             0         0.0         1
# 4         2417              0.0             1         0.0         0
#
#    name_length  num_order  org_facebook  org_twitter  sale_duration  \
# 0           60          0           0.0          0.0           29.0
# 1           27         23           0.0         12.0           28.0
# 2           28         19           0.0          0.0           54.0
# 3           21         39           0.0          0.0            0.0
# 4           66         30           0.0          0.0           63.0
#
#    sale_duration2  show_map  user_age  user_created  user_type
# 0              33         1        36    1259613950          1
# ...

# %%
smaller_df.columns
# Out:
# Index(['body_length', 'delivery_method', 'fb_published', 'has_header',
#        'has_logo', 'name_length', 'num_order', 'org_facebook', 'org_twitter',
#        'sale_duration', 'sale_duration2', 'show_map', 'user_age',
#        'user_created', 'user_type'],
#       dtype='object')
